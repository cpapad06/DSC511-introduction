# %% [markdown]
# # Lab01 - Introduction
#
# In this tutorial, we will explore the following tasks:
# - Installing Python libraries on Google Colab
# - Connecting Google Colab to Atlas MongoDB

# %% [markdown]
# ## Step 1: Setup packages
#
# We will need to install (i) the `pymongo` python library to create a new mongodb database and collection to store the data, and (ii) the `pandas` library as to help us to interact with a sample dataset easily.

# %%
# !pip install -q pymongo
# !pip install pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Step 2: Import packages, connect to mongo

# %%
# Import necessary packages
import pandas as pd
from pymongo import MongoClient
from bson.objectid import ObjectId

# %%
# TODO: copy paste your connection string (see slide 21, and REMEMBER to put your admin password in the string)
connection_string = f"mongodb+srv://cpapad06:mpFJcfmjeP39M4oE@dsc511.zrkskob.mongodb.net/?appName=DSC511"

# %%
# We create a MongoClient instance
client = MongoClient(connection_string)

# %%
# From that instance, we need to get the connection for the desired database
db = client.Lab01

# %%
# Let's see how the MongoClient object looks like
db
# Out:
# Database(MongoClient(host=['ac-qelzjpc-shard-00-00.zrkskob.mongodb.net:27017', 'ac-qelzjpc-shard-00-01.zrkskob.mongodb.net:27017', 'ac-qelzjpc-shard-00-02.zrkskob.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='DSC511', authsource='admin', replicaset='atlas-d9i9f0-shard-0', tls=True), 'Lab01')

# %%
collection = db['Weather']
collection
# Out:
# Collection(Database(MongoClient(host=['ac-qelzjpc-shard-00-00.zrkskob.mongodb.net:27017', 'ac-qelzjpc-shard-00-01.zrkskob.mongodb.net:27017', 'ac-qelzjpc-shard-00-02.zrkskob.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='DSC511', authsource='admin', replicaset='atlas-d9i9f0-shard-0', tls=True), 'Lab01'), 'Weather')

# %%
all_data = collection.find()
for document in all_data:
    print(document)
# Out:
# {'_id': ObjectId('6978bbdb69b93a0c987fc03e')}
